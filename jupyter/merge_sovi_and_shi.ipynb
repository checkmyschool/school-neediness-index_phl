# %%
import pandas as pd

# %%
sovi = pd.read_csv('./phil_sovi_updated.csv')
shi = pd.read_csv('./shi_for_sovi.csv')

# %%
print(sovi.columns)
print(shi.columns)
# Out:
# Index(['Unnamed: 0', 'GEOLEV2', 'sovi13', 'num_persons', 'num_female', 'sovi1',
#        'num_children', 'sovi2', 'num_elderly', 'sovi3',
#        'num_adults_no_sec_degree', 'sovi4', 'num_fem20_39_nodeg', 'sovi5',
#        'num_female_head', 'sovi6', 'overseas_hholds', 'num_hholds', 'sovi7',
#        'num_hhold_over30', 'sovi8', 'num_area10', 'sovi9', 'num_tenure',
#        'sovi10', 'num_disabled', 'sovi11', 'num_head_education', 'sovi12'],
#       dtype='object')
# Index(['School_Year', 'School_ID', 'School_Name', 'Region_Name',
#        'Division_Name', 'District_Name', 'Total_Enrollment', 'Comments',
#        'Original_Water_Boolean', 'Water_Boolean_Reversed',
#        'Original_Internet_Boolean', 'Internet_Boolean_Reversed',
#        'Original_Electricity_Boolean', 'Electricity_Boolean_Reversed',
#        'Instructional_Rooms', 'Student_Classroom_Ratio', 'Total_Teaching',
#        'Student_Teacher_Ratio', 'Latitude', 'Longitude', 'CNTRY_NAME',
# ...

# %%
sovi.columns = ['Unnamed: 0', 'GEOLEVEL2', 'sovi13', 'num_persons', 'num_female', 'sovi1',
       'num_children', 'sovi2', 'num_elderly', 'sovi3',
       'num_adults_no_sec_degree', 'sovi4', 'num_fem20_39_nodeg', 'sovi5',
       'num_female_head', 'sovi6', 'overseas_hholds', 'num_hholds', 'sovi7',
       'num_hhold_over30', 'sovi8', 'num_area10', 'sovi9', 'num_tenure',
       'sovi10', 'num_disabled', 'sovi11', 'num_head_education', 'sovi12']

# %%
merged = pd.merge(shi, sovi, on = 'GEOLEVEL2')

# %%
merged.head()
# Out:
#    School_Year  School_ID      School_Name Region_Name  \
# 0         2016     101746  A. Diaz, Sr. ES    Region I
# 1         2016     101747       Artacho ES    Region I
# 2         2016     101749      Bautista CS    Region I
# 3         2016     101697      Bersamin ES    Region I
# 4         2016     101699    Guinawedan ES    Region I
#
#               Division_Name District_Name  Total_Enrollment Comments  \
# 0  Pangasinan II, Binalonan      Bautista               789      NaN
# 1  Pangasinan II, Binalonan      Bautista               150      NaN
# 2  Pangasinan II, Binalonan      Bautista              1293      NaN
# 3  Pangasinan II, Binalonan        Alcala               496      NaN
# 4  Pangasinan II, Binalonan        Alcala               202      NaN
#
#    Original_Water_Boolean  Water_Boolean_Reversed    ...     num_hhold_over30  \
# 0                       1                       0    ...                151.0
# ...

# %%
merged.to_csv('./sovi_shi_combined_updated.csv')
